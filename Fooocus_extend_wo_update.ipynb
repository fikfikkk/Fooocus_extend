# %%
# @markdown # Select profile of Fooocus and start/restart

Fooocus_Profile = "realistic" #@param ["default", "realistic", "anime"]
Fooocus_Theme = "dark" #@param ["dark", "light"]

# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/shaitanzx/Fooocus_extend.git
# !mkdir /content/Fooocus_extend/batch_images

Memory_patch = True #@param {type:"boolean"}
patch=""
if Memory_patch == True :
    patch="--always-high-vram --all-in-fp16"

GoogleDrive_output = True #@param {type:"boolean"}
output_foder=""
if GoogleDrive_output == True :
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    output_foder="--output-path /content/drive/MyDrive/outputs"
    # !mkdir /content/drive/MyDrive/outputs

# %cd /content
# begin module for synchronization
# !pip install rembg==2.0.53
# end modulw for synchronization



# %cd /content/Fooocus_extend
#run foocus
if Fooocus_Profile=='default':
  profile=""
if Fooocus_Profile=='realistic':
  profile="--preset realistic"
if Fooocus_Profile=='anime':
  profile="--preset anime"

if Fooocus_Theme=='dark':
  theme="--theme dark"
if Fooocus_Theme=='light':
  theme=""

# !python launch.py {profile} {theme} --share {patch} {output_foder}
# Out:
# Collecting pygit2==1.12.2
#   Downloading pygit2-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.22)
# Installing collected packages: pygit2
# Successfully installed pygit2-1.12.2
# /content
# Cloning into 'Fooocus_extend'...
# remote: Enumerating objects: 6496, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 6496 (delta 118), reused 101 (delta 54), pack-reused 6280
# Receiving objects: 100% (6496/6496), 33.22 MiB | 18.62 MiB/s, done.
# Resolving deltas: 100% (3689/3689), done.
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/MyDrive/outputs’: File exists
# /content
# Collecting rembg==2.0.53
#   Downloading rembg-2.0.53-py3-none-any.whl (32 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (4.19.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (1.25.2)
# Collecting onnxruntime (from rembg==2.0.53)
#   Downloading onnxruntime-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (4.10.0.84)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (9.4.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (1.8.2)
# Collecting pymatting (from rembg==2.0.53)
#   Downloading PyMatting-1.1.12-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rembg==2.0.53) (4.66.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg==2.0.53) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg==2.0.53) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg==2.0.53) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->rembg==2.0.53) (0.19.0)
# Collecting coloredlogs (from onnxruntime->rembg==2.0.53)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg==2.0.53) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg==2.0.53) (24.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg==2.0.53) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->rembg==2.0.53) (1.13.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg==2.0.53) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->rembg==2.0.53) (2.31.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.10/dist-packages (from pymatting->rembg==2.0.53) (0.58.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg==2.0.53) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg==2.0.53) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg==2.0.53) (2024.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->rembg==2.0.53) (1.6.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba!=0.49.0->pymatting->rembg==2.0.53) (0.41.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg==2.0.53) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg==2.0.53) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg==2.0.53) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->rembg==2.0.53) (2024.7.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->rembg==2.0.53)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->rembg==2.0.53) (1.3.0)
# Installing collected packages: humanfriendly, pymatting, coloredlogs, onnxruntime, rembg
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.18.1 pymatting-1.1.12 rembg-2.0.53
# /content/Fooocus_extend
# [System ARGV] ['launch.py', '--preset', 'realistic', '--theme', 'dark', '--share', '--always-high-vram', '--all-in-fp16', '--output-path', '/content/drive/MyDrive/outputs']
# Python 3.10.12 (main, Mar 22 2024, 16:50:05) [GCC 11.4.0]
# Fooocus version: 2.5.0
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# Traceback (most recent call last):
#   File "/content/Fooocus_extend/launch.py", line 75, in <module>
#     prepare_environment()
#   File "/content/Fooocus_extend/launch.py", line 57, in prepare_environment
#     run_pip(f"install -r \"{requirements_file}\"", "requirements")
#   File "/content/Fooocus_extend/modules/launch_util.py", line 70, in run_pip
#     return run(f'"{python}" -m pip {command} --prefer-binary{index_url_line}', desc=f"Installing {desc}",
#   File "/content/Fooocus_extend/modules/launch_util.py", line 50, in run
#     result = subprocess.run(**run_kwargs)
#   File "/usr/lib/python3.10/subprocess.py", line 505, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1154, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 2021, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
# ^C
